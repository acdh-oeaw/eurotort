# %%
from archiv.utils import gsheet_to_df

# %%
sheet_id = "1JQmPMVEQ57Bxr7J9IwmOAhhITekXVfIhn0PAFkP3Uws"

# %%
df = gsheet_to_df(sheet_id)

# %%
df.head()

# %%
for i, row in df.iterrows():
    kw = KeyWord.objects.get(id=row["id"])
    kw.name = row["rename to"].strip()
    kw.save()
